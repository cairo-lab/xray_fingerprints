# %%
import glob
import os
import timm 
import torch
from torch.autograd import Variable

import numpy as np
import pandas as pd
from PIL import Image
import efficientnet.keras as efn

from torch import nn
from torch import optim
import torch.nn.functional as F
from torch.utils.data import Subset
from torchvision import transforms, models, datasets
from torchvision.transforms import Compose, ToTensor, Resize
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import train_test_split
from sklearn import preprocessing


METADATA_SUBSET_PATH = "/Users/franceskoback/Documents/research/pytorch_1/metadata_100subset_df.csv"

def get_manufacturer_labels(encoder, target_variable = "(0008, 0070) Manufacturer"):
    df = pd.read_csv(METADATA_SUBSET_PATH)
    df["id"] = df["id"].astype("str").str.zfill(8)
    df["code"] = encoder.fit_transform(df[target_variable])
    
    return {row["id"]: row["code"] for i, row in df.iterrows()}

class CustomImageDataset(Dataset):
    def __init__(self):
        self.img_dir = "/Users/franceskoback/Documents/research/pytorch_1/xray_subsets"

        self.images = glob.glob(os.path.join(self.img_dir, "*.npy")) 
        self.le = preprocessing.LabelEncoder()
        self.label_map = get_manufacturer_labels(self.le)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        image = Image.fromarray(np.load(img_path)).convert("RGB")
        image = transforms.ToTensor()(image)
        xray_id = os.path.basename(img_path).replace(".npy", "")
        
        return {"image": image, "label": self.label_map[xray_id]}

def train_val_test_dataset(dataset, val_split=0.20):
    train_idx, rem_idx = train_test_split(list(range(len(dataset))), test_size=val_split)

    Test_size=0.5 # split equally between validataion and test sets 

    val_idx, test_idx  = train_test_split(list(range(len(rem_idx))), test_size=Test_size)



    datasets = {}
    datasets['train'] = Subset(dataset, train_idx)
    datasets['val'] = Subset(dataset, val_idx)
    datasets['test'] = Subset(dataset, test_idx)
    return datasets

# %%
dataset = CustomImageDataset()
datasets = train_val_test_dataset(dataset)
print(len(datasets['train'].dataset)) #6
#datasets['train'].dataset, batch_size=params["batch_size"], shuffle=True
train_loader = DataLoader(
    datasets['train'].dataset, batch_size=3, shuffle=True
)
valid_loader = DataLoader(
    datasets['val'].dataset, batch_size=3, shuffle=True
)
test_loader = DataLoader(
    datasets['test'].dataset, batch_size=3, shuffle=True
)
print(len(train_loader.dataset)) #6 
len_train=len(datasets['train'])
len_val= len(datasets['val'])
len_test= len(datasets['test'])
print("Training length", len(datasets['train']))
print("Validation length", len(datasets['val']))
print("Testing length", len(datasets['test']))
# Out:
# 100
# 100
# Training length 80
# Validation length 10
# Testing length 10

# %%
def Net(num_classes):
    model = models.resnet50(pretrained=True)
    
    # Freeze parameters so we don't backprop through them
    for param in model.parameters():
        param.requires_grad = False

    from collections import OrderedDict
    classifier = nn.Sequential(OrderedDict([
                              ('fc1', nn.Linear(2048, 1024)),
                              ('relu', nn.ReLU()),
                              ('fc2', nn.Linear(1024, 256)),
                              ('relu', nn.ReLU()),
                              ('fc3', nn.Linear(256, num_classes)),
                              ('output', nn.LogSoftmax(dim=1))
                              ]))

    model.fc = classifier
    return model

params = {
    "model": "resnet50",
    #"device": "cuda",
    "lr": 0.001,
    "batch_size": 3, #64
    "num_workers": 1, #20
    "n_epochs": 50, #100
    "image_size": 224, 
    "in_channels": 3, #3
    "num_classes": 3, #12
    "device": "cpu"
}

model = Net(params['num_classes'])
model.to(params["device"])
#loss_fn = nn.NLLLoss() 
loss_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr = params['lr'])
# Out:
# /Users/franceskoback/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/franceskoback/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
def train_one_epoch(epoch, model, loss_fn, optimizer, train_loader, device = "cpu"):
    #put model in training state
    model.train()
    train_loss = 0.0
    

    for batch_idx, img_dicts in enumerate(train_loader,0):  
        inputs = img_dicts["image"] 
        labels = img_dicts["label"]  
        
        inputs = Variable(inputs.to(device).float())
        labels = Variable(labels.to(device).float())
        
        
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = model(inputs)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad() # sets all grads to None 

        # print statistics
        #running_loss += loss.item()
        #if i % 2000 == 1999:    # print every 2000 mini-batches
         #   print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 2000:.3f}')
            #running_loss=0
          #  i=i+1

        
        
        #
    
        train_loss+= ((1 / (batch_idx + 1)) * (loss.data.item() - train_loss))
        if batch_idx%5==0:
            print('train loss', train_loss)
    
    print('Epoch {} avg Training loss: {:.3f}'.format(epoch+1, train_loss))
    
    return model, train_loss

def test_one_epoch(epoch, model, loss_fn, loader, len_val, device = "cpu"):
    model.eval()
    
    #pbar = tqdm(enumerate(test_loader), total = len(test_loader))
    running_loss = 0
    actual_labels = []
    pred_labels = []
    
    #for step, (imgs, labels) in pbar:
    for batch_idx, img_dicts in enumerate(loader,0):    
        inputs = img_dicts["image"] 
        labels = img_dicts["label"] 
        
        inputs = Variable(inputs.to(device).float())
        labels = Variable(labels.to(device).float())
        
        log_preds = model(inputs)
        loss = loss_fn(log_preds, labels)
        
        preds = torch.exp(log_preds)
        running_loss+=((1 / (batch_idx + 1)) * (loss.data.item() - running_loss))
        
        #calculate accuracy
        top_prob, top_class = preds.topk(1, dim=1)
        pred_labels+= list((top_class.view(-1)).cpu().numpy())
        actual_labels+= list(labels.cpu().numpy())
        
        
    
    accuracy = ((np.array(pred_labels)==np.array(actual_labels)).sum())/np.array(actual_labels).size #size of test set
    correct = ((np.array(pred_labels)==np.array(actual_labels)).sum())
    total = np.array(actual_labels).size
    
    
    return running_loss, accuracy, correct, total

# %% [markdown]
# ## Training Loop

# %%
train_losses = []
valid_losses = []

for epoch in range(params['n_epochs']):
    train_loss = train_one_epoch(epoch, model, loss_fn, optimizer, train_loader)
    train_losses+= [train_loss]
    valid_loss, accuracy, correct, total = test_one_epoch(epoch, model, loss_fn, valid_loader, len_val)
    valid_losses+=[valid_loss]
    print('Epoch {} avg Valid loss: {:.3f}'.format(epoch+1, valid_loss))
    print('Epoch {} Valid accuracy: {:.1%} ({} of {} right)\n'.format(epoch+1, accuracy, correct, total))
    if len(valid_losses)>1 and (valid_loss<min(valid_losses[:-1])):
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': loss_fn,
            }, 'checkpoint.tar')
# Out:
# train loss 45.9112434387207
# train loss 29.364959557851158
# train loss 30.16519849950617
# train loss 32.555523574352264
# train loss 30.79437151409331
# train loss 32.29194468718308
# train loss 31.849944899159095
# Epoch 1 avg Training loss: 31.833
# Epoch 1 avg Valid loss: 32.950
# Epoch 1 Valid accuracy: 19.0% (19 of 100 right)
#
# train loss 14.21153736114502
# train loss 29.027318636576332
# train loss 33.15225592526522
# train loss 31.859409928321835
# train loss 35.89028599148705
# train loss 32.70231793476985
# train loss 32.78818561953883
# Epoch 2 avg Training loss: 31.353
# Epoch 2 avg Valid loss: 32.309
# Epoch 2 Valid accuracy: 7.0% (7 of 100 right)
#
# train loss 53.08612823486328
# train loss 20.621692260106403
# train loss 31.424679799513385
# train loss 30.77838990092278
# train loss 29.898253327324277
# train loss 31.840714638049786
# train loss 32.039041896020215
# Epoch 3 avg Training loss: 31.343
# Epoch 3 avg Valid loss: 32.059
# Epoch 3 Valid accuracy: 7.0% (7 of 100 right)
#
# train loss 14.24166202545166
# train loss 30.52998447418213
# train loss 30.761910080909733
# train loss 33.119668774306774
# train loss 32.51831235772088
# train loss 32.66178475434964
# train loss 33.14743610735862
# Epoch 4 avg Training loss: 31.346
# Epoch 4 avg Valid loss: 31.352
# Epoch 4 Valid accuracy: 7.0% (7 of 100 right)
#
# train loss 22.943193435668945
# train loss 34.242710272471115
# train loss 31.03277007016268
# train loss 27.71130749583244
# train loss 25.30389710835048
# train loss 26.742025852203366
# train loss 29.494173695964196
# Epoch 5 avg Training loss: 32.950
# Epoch 5 avg Valid loss: 31.345
# Epoch 5 Valid accuracy: 7.0% (7 of 100 right)
#
# train loss 17.584707260131836
# train loss 25.8482399781545
# train loss 32.7166523066434
# train loss 30.433154642581936
# train loss 30.75687417529878
# train loss 31.537977695465084
# train loss 29.825009099898793
# Epoch 6 avg Training loss: 32.937
# Epoch 6 avg Valid loss: 32.938
# Epoch 6 Valid accuracy: 7.0% (7 of 100 right)
#
# train loss 39.38175964355469
# train loss 23.31642325719198
# train loss 27.223770054903902
# train loss 27.11816164851189
# train loss 29.788280101049516
# train loss 29.84950573627766
# train loss 31.83013431487545
# Epoch 7 avg Training loss: 31.658
# Epoch 7 avg Valid loss: 31.818
# Epoch 7 Valid accuracy: 17.0% (17 of 100 right)
#
# train loss 15.293804168701172
# train loss 21.911418279012047
# train loss 26.02739178050648
# train loss 29.037442445755005
# train loss 30.112051691327775
# train loss 30.98927226433387
# train loss 30.998274403233683
# Epoch 8 avg Training loss: 32.959
# Epoch 8 avg Valid loss: 31.345
# Epoch 8 Valid accuracy: 17.0% (17 of 100 right)
#
# train loss 10.589725494384766
# train loss 20.1599178314209
# train loss 22.19414047761397
# train loss 24.947348207235336
# train loss 24.433518352962672
# train loss 28.05427829118875
# train loss 31.731604414601478
# Epoch 9 avg Training loss: 31.300
# Epoch 9 avg Valid loss: 31.387
# Epoch 9 Valid accuracy: 17.0% (17 of 100 right)
#
# train loss 46.10971450805664
# train loss 27.302471160888672
# train loss 37.01640025052158
# train loss 35.18482303619385
# train loss 36.530460266839896
# train loss 34.52353538458165
# train loss 33.49099425731168
# Epoch 10 avg Training loss: 31.455
# Epoch 10 avg Valid loss: 31.861
# Epoch 10 Valid accuracy: 17.0% (17 of 100 right)
#
# train loss 51.7149658203125
# train loss 32.01850732167562
# train loss 25.47830616344105
# train loss 29.179502025246624
# train loss 31.080805017834617
# train loss 29.613805789213917
# train loss 30.875433906432125
# Epoch 11 avg Training loss: 31.796
# Epoch 11 avg Valid loss: 32.933
# Epoch 11 Valid accuracy: 17.0% (17 of 100 right)
#
# train loss 18.711454391479492
# train loss 28.50910679499308
# train loss 29.5098312551325
# train loss 27.232032567262646
# train loss 26.655866327739894
# train loss 28.229789422108578
# train loss 31.058537252487678
# Epoch 12 avg Training loss: 33.332
# Epoch 12 avg Valid loss: 31.331
# Epoch 12 Valid accuracy: 17.0% (17 of 100 right)
#
# train loss 10.36009407043457
# train loss 21.10573228200277
# train loss 26.985659859397195
# train loss 28.479697823524475
# train loss 30.95661390395392
# train loss 34.70167438800519
# train loss 32.41411781311036
# Epoch 13 avg Training loss: 31.412
# Epoch 13 avg Valid loss: 33.369
# Epoch 13 Valid accuracy: 17.0% (17 of 100 right)
#
# train loss 37.061866760253906
# train loss 30.466846783955894
# train loss 32.606313878839664
# train loss 29.54371209442615
# train loss 30.834937697365167
# train loss 29.69969335886148
# train loss 32.15168067716783
# Epoch 14 avg Training loss: 31.313
# Epoch 14 avg Valid loss: 33.354
# Epoch 14 Valid accuracy: 17.0% (17 of 100 right)
#
# train loss 6.1953125
# train loss 22.599760850270588
# train loss 30.014345515858043
# train loss 30.529784798622135
# train loss 28.521127995990575
# train loss 29.869502929540786
# train loss 32.73777228017008
# Epoch 15 avg Training loss: 31.433
# Epoch 15 avg Valid loss: 31.466
# Epoch 15 Valid accuracy: 17.0% (17 of 100 right)
#
# train loss 17.79615020751953
# train loss 22.42692995071411
# train loss 26.705507191744715
# train loss 33.66391831636429
# train loss 31.382143747238885
# train loss 30.878553610581612
# train loss 31.68911323239726
# Epoch 16 avg Training loss: 32.959
# Epoch 16 avg Valid loss: 31.828
# Epoch 16 Valid accuracy: 17.0% (17 of 100 right)
#
# train loss 32.22389602661133
# train loss 26.735090255737305
# train loss 27.648307540199973
# train loss 29.24518662691116
# train loss 29.2793056397211
# train loss 27.519185753969044
# train loss 31.828495110234904
# Epoch 17 avg Training loss: 32.951
# Epoch 17 avg Valid loss: 31.404
# Epoch 17 Valid accuracy: 17.0% (17 of 100 right)
#
# train loss 61.95717239379883
# train loss 44.674502054850265
# train loss 33.41920961033214
# train loss 36.83457139134407
# train loss 37.57309670675368
# train loss 33.72823133835425
# train loss 32.481828858775465
# Epoch 18 avg Training loss: 31.343
# Epoch 18 avg Valid loss: 31.329
# Epoch 18 Valid accuracy: 17.0% (17 of 100 right)
#
# train loss 5.048006057739258
# train loss 25.06626256306966
# train loss 25.845969330180775
# train loss 27.732542008161545
# train loss 27.33098808924357
# train loss 29.685234528321484
# train loss 30.865084271277144
# Epoch 19 avg Training loss: 31.521
# Epoch 19 avg Valid loss: 31.341
# Epoch 19 Valid accuracy: 7.0% (7 of 100 right)
#
# train loss 8.537022590637207
# train loss 28.405537088712055
# train loss 31.79644833911549
# train loss 34.17816738784314
# train loss 30.822269859768095
# train loss 31.948614386411816
# train loss 31.868023510902155
# Epoch 20 avg Training loss: 31.409
# Epoch 20 avg Valid loss: 31.836
# Epoch 20 Valid accuracy: 19.0% (19 of 100 right)
#
# train loss 44.97077560424805
# train loss 22.29122308890025
# train loss 29.23248757015575
# train loss 31.713740572333336
# train loss 30.98133131435939
# train loss 32.44338357448578
# train loss 32.13586455775846
# Epoch 21 avg Training loss: 31.354
# Epoch 21 avg Valid loss: 31.840
# Epoch 21 Valid accuracy: 7.0% (7 of 100 right)
#
# train loss 14.33369255065918
# train loss 29.325740019480385
# train loss 33.84990197961981
# train loss 33.981288135051734
# train loss 32.07643003690811
# train loss 32.59530730430897
# train loss 32.65970207798866
# Epoch 22 avg Training loss: 32.947
# Epoch 22 avg Valid loss: 31.370
# Epoch 22 Valid accuracy: 19.0% (19 of 100 right)
#
# train loss 3.3268418312072754
# train loss 22.304840008417766
# train loss 27.318782329559326
# train loss 30.238414674997326
# train loss 35.596798783256894
# train loss 32.663368610235366
# train loss 32.98320273430117
# Epoch 23 avg Training loss: 31.504
# Epoch 23 avg Valid loss: 31.390
# Epoch 23 Valid accuracy: 19.0% (19 of 100 right)
#
# train loss 11.587199211120605
# train loss 36.341449896494545
# train loss 27.932353323156182
# train loss 28.862828344106674
# train loss 32.127489703042166
# train loss 33.41761741271386
# train loss 31.948650452398486
# Epoch 24 avg Training loss: 32.956
# Epoch 24 avg Valid loss: 31.352
# Epoch 24 Valid accuracy: 19.0% (19 of 100 right)
#
# train loss 26.87964630126953
# train loss 34.69312779108684
# train loss 37.18827707117254
# train loss 38.27137932181358
# train loss 33.939586054711114
# train loss 33.36249803121273
# train loss 33.48136693046939
# Epoch 25 avg Training loss: 31.409
# Epoch 25 avg Valid loss: 31.409
# Epoch 25 Valid accuracy: 19.0% (19 of 100 right)
#
# train loss 40.01484680175781
# train loss 35.32758712768555
# train loss 33.02550636638294
# train loss 32.97436779737472
# train loss 33.86381884983607
# train loss 33.06249684553879
# train loss 31.783636285412687
# Epoch 26 avg Training loss: 32.927
# Epoch 26 avg Valid loss: 32.942
# Epoch 26 Valid accuracy: 17.0% (17 of 100 right)
#
# train loss 39.25078582763672
# train loss 31.616499344507854
# train loss 28.375591234727338
# train loss 30.668537631630898
# train loss 29.729047786621816
# train loss 33.64098740541017
# train loss 32.08681736453887
# Epoch 27 avg Training loss: 31.474
# Epoch 27 avg Valid loss: 31.401
# Epoch 27 Valid accuracy: 17.0% (17 of 100 right)
#
# train loss 21.54998779296875
# train loss 49.51023483276367
# train loss 42.5802921815352
# train loss 36.81688889861107
# train loss 32.09522631054833
# train loss 33.372837158349846
# train loss 32.29792931002955
# Epoch 28 avg Training loss: 32.322
# Epoch 28 avg Valid loss: 32.943
# Epoch 28 Valid accuracy: 17.0% (17 of 100 right)
#
# train loss 18.74013328552246
# train loss 30.635450681050617
# train loss 30.238846865567293
# train loss 33.930284440517426
# train loss 34.05100375130063
# train loss 33.18496140149923
# train loss 31.95485254256956
# Epoch 29 avg Training loss: 31.818
# Epoch 29 avg Valid loss: 31.410
# Epoch 29 Valid accuracy: 17.0% (17 of 100 right)
#
# train loss 13.393314361572266
# train loss 21.430984338124592
# train loss 26.593850525942717
# train loss 30.55483087897301
# train loss 30.438755920955117
# train loss 32.42683914991525
# train loss 32.900189415101075
# Epoch 30 avg Training loss: 31.668
# Epoch 30 avg Valid loss: 31.390
# Epoch 30 Valid accuracy: 17.0% (17 of 100 right)
#
# train loss 44.84160614013672
# train loss 34.385208527247116
# train loss 41.52708161960948
# train loss 31.811281345784657
# train loss 30.720324124608712
# train loss 29.203931675507466
# train loss 31.44771890870986
# Epoch 31 avg Training loss: 32.320
# Epoch 31 avg Valid loss: 32.957
# Epoch 31 Valid accuracy: 17.0% (17 of 100 right)
#
# train loss 56.59646224975586
# train loss 36.88377674420675
# train loss 38.223941672932014
# train loss 38.35362032055854
# train loss 36.38956608091081
# train loss 33.63884232594416
# train loss 31.187910679847956
# Epoch 32 avg Training loss: 31.337
# Epoch 32 avg Valid loss: 32.923
# Epoch 32 Valid accuracy: 17.0% (17 of 100 right)
#
# train loss 31.08595085144043
# train loss 33.45985682805379
# train loss 33.159706896001644
# train loss 32.58966255187988
# train loss 30.89119661422003
# train loss 31.862613567939167
# train loss 31.805749277914725
# Epoch 33 avg Training loss: 31.388
# Epoch 33 avg Valid loss: 31.826
# Epoch 33 Valid accuracy: 17.0% (17 of 100 right)
#
# train loss 30.681779861450195
# train loss 22.06255344549815
# train loss 28.215961597182535
# train loss 29.25674495846033
# train loss 31.054738913263595
# train loss 31.21172619324464
# train loss 31.214660463794583
# Epoch 34 avg Training loss: 32.973
# Epoch 34 avg Valid loss: 31.396
# Epoch 34 Valid accuracy: 17.0% (17 of 100 right)
#
# train loss 17.60015106201172
# train loss 36.883789499600724
# train loss 30.753442244096238
# train loss 27.854874521493915
# train loss 30.5412453469776
# train loss 28.167816217129047
# train loss 30.90376778571836
# Epoch 35 avg Training loss: 32.315
# Epoch 35 avg Valid loss: 32.951
# Epoch 35 Valid accuracy: 7.0% (7 of 100 right)
#
# train loss 64.75616455078125
# train loss 37.77093315124512
# train loss 38.082844127308235
# train loss 34.81194832921028
# train loss 33.59523988905407
# train loss 32.73464601773482
# train loss 32.20928386718996
# Epoch 36 avg Training loss: 31.347
# Epoch 36 avg Valid loss: 31.357
# Epoch 36 Valid accuracy: 7.0% (7 of 100 right)
#
# train loss 36.754459381103516
# train loss 32.10193260510763
# train loss 29.266266866163775
# train loss 26.01929178833962
# train loss 29.715515976860413
# train loss 30.086214469029358
# train loss 31.68282413482666
# Epoch 37 avg Training loss: 32.315
# Epoch 37 avg Valid loss: 31.406
# Epoch 37 Valid accuracy: 19.0% (19 of 100 right)
#
# train loss 41.89855194091797
# train loss 35.91968854268392
# train loss 40.411973389712244
# train loss 36.77703782916069
# train loss 32.44034079142979
# train loss 32.594822975305405
# train loss 31.21977300028647
# Epoch 38 avg Training loss: 32.925
# Epoch 38 avg Valid loss: 32.940
# Epoch 38 Valid accuracy: 19.0% (19 of 100 right)
#
# train loss 26.00187110900879
# train loss 39.92527834574381
# train loss 35.87057883089239
# train loss 30.89037089049816
# train loss 33.93124856267657
# train loss 32.08152880118444
# train loss 31.877206179403494
# Epoch 39 avg Training loss: 31.659
# Epoch 39 avg Valid loss: 31.811
# Epoch 39 Valid accuracy: 19.0% (19 of 100 right)
#
# train loss 36.57190704345703
# train loss 36.48891353607178
# train loss 33.233515522696756
# train loss 35.062316089868546
# train loss 35.70859021232241
# train loss 32.78210995747493
# train loss 31.770779848098755
# Epoch 40 avg Training loss: 31.332
# Epoch 40 avg Valid loss: 31.520
# Epoch 40 Valid accuracy: 19.0% (19 of 100 right)
#
# train loss 67.09247589111328
# train loss 39.019708951314286
# train loss 36.812412717125625
# train loss 39.05621452629566
# train loss 37.283088377543855
# train loss 35.35530395691211
# train loss 32.511946639707006
# Epoch 41 avg Training loss: 31.339
# Epoch 41 avg Valid loss: 32.975
# Epoch 41 Valid accuracy: 19.0% (19 of 100 right)
#
# train loss 18.889585494995117
# train loss 28.75508769353231
# train loss 36.98079772429033
# train loss 38.86383274197579
# train loss 35.20364902133034
# train loss 32.16620588302613
# train loss 32.33597664679251
# Epoch 42 avg Training loss: 31.355
# Epoch 42 avg Valid loss: 32.946
# Epoch 42 Valid accuracy: 19.0% (19 of 100 right)
#
# train loss 61.9281005859375
# train loss 31.853048563003536
# train loss 34.516514301300056
# train loss 29.894310772418983
# train loss 29.63071237291609
# train loss 34.28525356146006
# train loss 32.585047783390166
# Epoch 43 avg Training loss: 31.347
# Epoch 43 avg Valid loss: 31.400
# Epoch 43 Valid accuracy: 19.0% (19 of 100 right)
#
# train loss 37.80707550048828
# train loss 37.76667579015096
# train loss 37.249703754078254
# train loss 31.22552870213986
# train loss 31.336382718313317
# train loss 29.892423767309932
# train loss 31.863806070819983
# Epoch 44 avg Training loss: 31.480
# Epoch 44 avg Valid loss: 32.938
# Epoch 44 Valid accuracy: 19.0% (19 of 100 right)
#
# train loss 44.91126251220703
# train loss 32.68704970677693
# train loss 30.98291709206321
# train loss 29.12577711045742
# train loss 32.677657116027106
# train loss 31.841102081995746
# train loss 32.01977840162093
# Epoch 45 avg Training loss: 32.935
# Epoch 45 avg Valid loss: 31.837
# Epoch 45 Valid accuracy: 7.0% (7 of 100 right)
#
# train loss 15.012516975402832
# train loss 30.568907817204792
# train loss 32.52445311979814
# train loss 27.74260324239731
# train loss 28.626542034603304
# train loss 29.382501262884876
# train loss 31.08061841995486
# Epoch 46 avg Training loss: 31.822
# Epoch 46 avg Valid loss: 31.387
# Epoch 46 Valid accuracy: 7.0% (7 of 100 right)
#
# train loss 10.589309692382812
# train loss 34.41860930124919
# train loss 28.916054010391235
# train loss 28.43586139380932
# train loss 26.182244686853316
# train loss 30.557786116233235
# train loss 31.338862496037635
# Epoch 47 avg Training loss: 31.335
# Epoch 47 avg Valid loss: 31.404
# Epoch 47 Valid accuracy: 7.0% (7 of 100 right)
#
# train loss 7.57850456237793
# train loss 26.81866375605265
# train loss 31.767464247616854
# train loss 28.822622627019882
# train loss 31.112035910288494
# train loss 31.60000175696153
# train loss 31.82917470316733
# Epoch 48 avg Training loss: 31.839
# Epoch 48 avg Valid loss: 31.408
# Epoch 48 Valid accuracy: 7.0% (7 of 100 right)
#
# train loss 7.404335021972656
# train loss 45.28423511981964
# train loss 40.37187669493936
# train loss 36.26789130270482
# train loss 36.39256212824868
# train loss 32.52248047865355
# train loss 33.4021159987296
# Epoch 49 avg Training loss: 31.840
# Epoch 49 avg Valid loss: 31.832
# Epoch 49 Valid accuracy: 7.0% (7 of 100 right)
#
# train loss 44.94847106933594
# train loss 32.789076169331864
# train loss 34.067513639276676
# train loss 28.42367115616798
# train loss 25.339749495188396
# train loss 29.2433131474715
# train loss 32.52192443416964
# Epoch 50 avg Training loss: 31.605
# Epoch 50 avg Valid loss: 32.986
# Epoch 50 Valid accuracy: 7.0% (7 of 100 right)

# %%
# load the model that got the best validation accuracy
checkpoint = torch.load('checkpoint.tar')
loaded_model = Net(params['num_classes'])
loaded_model.to(params["device"])
loaded_model.load_state_dict(checkpoint['model_state_dict'])

loaded_criterion = checkpoint['loss']

#optimizer = optim.Adam(model.parameters(), lr = 0.003)
#optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

last_epoch = checkpoint['epoch']+1

test_loss, accuracy, correct, total = test_one_epoch(None, loaded_model, loaded_criterion, test_loader, len_val)

print('Test loss: {:.3f}'.format(test_loss))
print('Test accuracy: {:.1%} ({} of {} right)\n'.format(accuracy, correct, total))
# Out:
# /Users/franceskoback/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/franceskoback/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Test loss: 31.650
# Test accuracy: 17.0% (17 of 100 right)
